# %%
import torch

# %%
print("PyTorch:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
x = torch.randn(4096, 4096, device=device)
y = x @ x
print("device:", y.device)
# Out:
# PyTorch: 2.2.2
# MPS available: True
# MPS built: True
# device: mps:0

# %%
import os
os.chdir("/Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/main_semi_test_new")

# %%
h5ad_dir = "/Users/apple/Desktop/KB/data/Cell_tag-Cell_tag_multi_integrated/Seurat_method/cellTag_test_multi_Seurat_clone_id.h5ad"
ckpt_dir = "/Users/apple/Desktop/KB/data/feat_LCL_2025/Cell_tag-Cell_tag_multi"

Out_dir_1 = "/Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty"
Out_dir_2 = "/Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty"

ckpt_file_1 = ckpt_dir + "/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
ckpt_file_2 = ckpt_dir + "/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"

# %%
# !python run_ig_cosine_centroid.py \
  --inputFilePath {h5ad_dir} \
  --resume_from_checkpoint {ckpt_file_1} \
  --output_dir {Out_dir_1} \
  --batch_size 250
# Out:
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# Checkpoint /Users/apple/Desktop/KB/data/feat_LCL_2025/Cell_tag-Cell_tag_multi/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt was loaded to cpu
# Computing z = g(f(x)) for all cells...
# Running IG on 30 clones...
# [1/30] clone=64854.0  n_cells=117
# [2/30] clone=63942.0  n_cells=17
# [3/30] clone=61713.0  n_cells=12
# [4/30] clone=59576.0  n_cells=55
# [5/30] clone=46616.0  n_cells=11
# [6/30] clone=63638.0  n_cells=23
# [7/30] clone=56911.0  n_cells=10
# [8/30] clone=64935.0  n_cells=60
# [9/30] clone=51165.0  n_cells=18
# [10/30] clone=60138.0  n_cells=13
# [11/30] clone=61206.0  n_cells=19
# [12/30] clone=19762.0  n_cells=12
# [13/30] clone=62242.0  n_cells=39
# [14/30] clone=31799.0  n_cells=17
# [15/30] clone=62342.0  n_cells=11
# [16/30] clone=57941.0  n_cells=21
# [17/30] clone=21808.0  n_cells=12
# [18/30] clone=60275.0  n_cells=20
# [19/30] clone=60662.0  n_cells=36
# [20/30] clone=3787.0  n_cells=20
# [21/30] clone=20974.0  n_cells=10
# [22/30] clone=64461.0  n_cells=28
# [23/30] clone=31264.0  n_cells=78
# [24/30] clone=61068.0  n_cells=17
# [25/30] clone=64326.0  n_cells=23
# [26/30] clone=56158.0  n_cells=10
# [27/30] clone=29556.0  n_cells=18
# [28/30] clone=50331.0  n_cells=28
# [29/30] clone=24642.0  n_cells=533
# [30/30] clone=55678.0  n_cells=10
# Done.
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/ig_cosine_centroid_global_gene_scores.npy
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/ig_cosine_centroid_global_top100.txt (if gene names available)
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/ig_cosine_centroid_clone_delta_summary.txt
# Baseline=zero, n_steps=100

# %%
# !python run_ig_cosine_centroid.py \
  --inputFilePath {h5ad_dir} \
  --resume_from_checkpoint {ckpt_file_2} \
  --output_dir {Out_dir_2} \
  --batch_size 250
# Out:
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /opt/anaconda3/envs/LCL/lib/python3.10/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# Checkpoint /Users/apple/Desktop/KB/data/feat_LCL_2025/Cell_tag-Cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt was loaded to cpu
# Computing z = g(f(x)) for all cells...
# Running IG on 30 clones...
# [1/30] clone=64854.0  n_cells=117
# [2/30] clone=63942.0  n_cells=17
# [3/30] clone=61713.0  n_cells=12
# [4/30] clone=59576.0  n_cells=55
# [5/30] clone=46616.0  n_cells=11
# [6/30] clone=63638.0  n_cells=23
# [7/30] clone=56911.0  n_cells=10
# [8/30] clone=64935.0  n_cells=60
# [9/30] clone=51165.0  n_cells=18
# [10/30] clone=60138.0  n_cells=13
# [11/30] clone=61206.0  n_cells=19
# [12/30] clone=19762.0  n_cells=12
# [13/30] clone=62242.0  n_cells=39
# [14/30] clone=31799.0  n_cells=17
# [15/30] clone=62342.0  n_cells=11
# [16/30] clone=57941.0  n_cells=21
# [17/30] clone=21808.0  n_cells=12
# [18/30] clone=60275.0  n_cells=20
# [19/30] clone=60662.0  n_cells=36
# [20/30] clone=3787.0  n_cells=20
# [21/30] clone=20974.0  n_cells=10
# [22/30] clone=64461.0  n_cells=28
# [23/30] clone=31264.0  n_cells=78
# [24/30] clone=61068.0  n_cells=17
# [25/30] clone=64326.0  n_cells=23
# [26/30] clone=56158.0  n_cells=10
# [27/30] clone=29556.0  n_cells=18
# [28/30] clone=50331.0  n_cells=28
# [29/30] clone=24642.0  n_cells=533
# [30/30] clone=55678.0  n_cells=10
# Done.
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/ig_cosine_centroid_global_gene_scores.npy
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/ig_cosine_centroid_global_top100.txt (if gene names available)
# Saved: /Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/ig_cosine_centroid_clone_delta_summary.txt
# Baseline=zero, n_steps=100

# %% [markdown]
# ### Result

# %%
import numpy as np
import pandas as pd
import anndata as ad

# %%
out_dir = "/Users/apple/Desktop/KB/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_LCL_2025/cell_tag_multi"
scores_1 = np.load(f"{out_dir}/feat_celltagMulti_lambda001_unlab15_bs250_testAsPenalty/ig_cosine_centroid_global_gene_scores.npy")
scores_2 = np.load(f"{out_dir}/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/ig_cosine_centroid_global_gene_scores.npy")

print(scores_1.shape, scores_1.min(), scores_1.max())
print(scores_2.shape, scores_2.min(), scores_2.max())
# Out:
# (1960,) 5.8039127e-06 0.016122213
# (1960,) 9.076306e-06 0.022723826

# %%
adata = ad.read_h5ad(h5ad_dir)  # or put the full path
genes = np.array(adata.var_names)

df = pd.DataFrame({"gene": genes, "score_1": scores_1, "score_2": scores_2})
df.head(30)
# Out:
#          gene   score_1   score_2
# 0      Igfbp5  0.001534  0.002005
# 1        Psca  0.003550  0.003520
# 2      Spink1  0.007013  0.012681
# 3         Fgb  0.005424  0.005994
# 4        Mmp3  0.001424  0.002140
# 5        Kng1  0.012518  0.015416
# 6        Ccl2  0.003126  0.003698
# 7        Saa3  0.000735  0.001046
# 8       Krt18  0.003086  0.004166
# 9         Alb  0.001237  0.001514
# 10  Serpina3n  0.003098  0.003018
# 11     Cdkn1c  0.005912  0.006776
# 12         Hp  0.001327  0.001373
# 13      Grem1  0.008361  0.008562
# 14       Rbp2  0.001081  0.000964
# 15      Ifit1  0.001930  0.002108
# 16      Acta1  0.006062  0.007186
# 17       Bex1  0.002257  0.003252
# 18      Crip1  0.003398  0.004656
# 19      Isg15  0.000944  0.001522
# 20      Elobl  0.000331  0.000413
# 21        Hdc  0.000725  0.001168
# 22        Clu  0.004758  0.005508
# 23       Apod  0.001907  0.002309
# 24  Serpina1b  0.001658  0.001732
# 25       Spp1  0.005339  0.005816
# 26      Apoa1  0.016122  0.022724
# 27       Areg  0.002532  0.002946
# 28    Col10a1  0.007561  0.007266
# 29      Cxcl5  0.000581  0.000735

# %%
df["rank_1"] = df["score_1"].rank(ascending=False, method="average")
df["rank_2"] = df["score_2"].rank(ascending=False, method="average")

# %%
from scipy.stats import spearmanr

rho, p = spearmanr(df["score_1"], df["score_2"])
rho
# Out:
# 0.9772631603641705
