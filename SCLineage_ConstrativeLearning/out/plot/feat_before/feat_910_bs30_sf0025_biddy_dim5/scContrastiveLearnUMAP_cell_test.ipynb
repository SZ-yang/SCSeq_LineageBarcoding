# %% [markdown]
# ## seaborn

# %%
import numpy as np
import umap
import matplotlib.pyplot as plt
from collections import Counter
import anndata as ad
import seaborn as sns

input_dir = "/Users/apple/Desktop/KB/data"
# output_dir = "/Users/apple/Desktop/KB/SCSeq_LineageBarcoding2/SCSeq_LineageBarcoding/SCLineage_ConstrativeLearning/out/plot/feat_713_colab"
output_dir = ""
num_top_lg_toplot = 5

# Load dataset
data = np.load(input_dir+'/feat_910_bs30_sf0025_biddy_dim5/test_embedding.npy')
adata_subset = ad.read_h5ad(input_dir+'/BiddyData/Biddy_test.h5ad')
adata_subset.obs['Cell type annotation'] = adata_subset.obs["cell_type"]
adata_subset.obs['Cell type annotation'] = adata_subset.obs['Cell type annotation'].cat.add_categories('Non Differentiated')
# Replace NaN values with 'Non Differentiated'
adata_subset.obs['Cell type annotation'].fillna('Non Differentiated', inplace=True)

labels = adata_subset.obs["clone_id"].to_numpy()
num_cells = labels.shape[0]

categories = adata_subset.obs['Cell type annotation'].to_numpy()  

print("data shape", data.shape)
print("labels shape", num_cells)
# Out:
# data shape (995, 5)
# labels shape 995

# %%
adata_subset.obs['Cell type annotation'].unique()
# Out:
# ['Non Differentiated', 'iEP', 'Ambiguous', 'Fibroblast']
# Categories (4, object): ['Ambiguous', 'Fibroblast', 'iEP', 'Non Differentiated']

# %%
# Initialize UMAP and fit the data
reducer = umap.UMAP()
embedding = reducer.fit_transform(data)

# %%
categories
# Out:
# array(['Non Differentiated', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'iEP', 'iEP', 'Ambiguous', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'Ambiguous', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'iEP', 'iEP', 'iEP', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'iEP', 'iEP', 'iEP', 'Non Differentiated', 'Ambiguous', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'iEP', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'iEP',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'iEP', 'iEP', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'Fibroblast', 'Non Differentiated', 'iEP', 'iEP', 'Fibroblast',
#        'iEP', 'Fibroblast', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Ambiguous', 'Non Differentiated',
#        'iEP', 'iEP', 'iEP', 'Ambiguous', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'Non Differentiated', 'iEP',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'iEP', 'Fibroblast', 'Non Differentiated', 'Ambiguous', 'iEP',
#        'iEP', 'iEP', 'Ambiguous', 'iEP', 'iEP', 'Non Differentiated',
#        'Ambiguous', 'iEP', 'iEP', 'iEP', 'Non Differentiated', 'iEP',
#        'iEP', 'iEP', 'iEP', 'iEP', 'Fibroblast', 'iEP', 'iEP', 'iEP',
#        'iEP', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'iEP', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'iEP', 'Fibroblast', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'iEP', 'Non Differentiated', 'iEP', 'iEP', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Non Differentiated', 'iEP',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'Ambiguous', 'Ambiguous',
#        'Non Differentiated', 'Ambiguous', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Fibroblast', 'iEP', 'Non Differentiated', 'Fibroblast', 'iEP',
#        'Fibroblast', 'Fibroblast', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'iEP', 'iEP', 'Fibroblast', 'iEP',
#        'Fibroblast', 'iEP', 'Fibroblast', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Non Differentiated', 'iEP',
#        'Ambiguous', 'Fibroblast', 'Fibroblast', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'Non Differentiated',
#        'Ambiguous', 'Ambiguous', 'Fibroblast', 'Non Differentiated',
#        'Ambiguous', 'iEP', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Ambiguous', 'Fibroblast', 'Fibroblast',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'Fibroblast', 'Fibroblast',
#        'iEP', 'Ambiguous', 'Non Differentiated', 'iEP', 'Fibroblast',
#        'Fibroblast', 'Ambiguous', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'Fibroblast',
#        'Fibroblast', 'Non Differentiated', 'Fibroblast', 'Ambiguous',
#        'iEP', 'Fibroblast', 'iEP', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Fibroblast', 'Ambiguous', 'iEP',
#        'Non Differentiated', 'Ambiguous', 'Ambiguous', 'Fibroblast',
#        'Ambiguous', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Ambiguous', 'Ambiguous', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Fibroblast', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Ambiguous', 'Ambiguous', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Fibroblast', 'Non Differentiated', 'Ambiguous', 'iEP', 'iEP',
#        'Fibroblast', 'Non Differentiated', 'Ambiguous', 'iEP',
#        'Fibroblast', 'iEP', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'Fibroblast', 'Fibroblast', 'Ambiguous', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'Ambiguous', 'Ambiguous', 'iEP',
#        'Fibroblast', 'iEP', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'Ambiguous', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'iEP', 'iEP', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'iEP', 'iEP', 'Non Differentiated', 'Ambiguous', 'Ambiguous',
#        'Ambiguous', 'iEP', 'Ambiguous', 'iEP', 'Ambiguous', 'iEP',
#        'Ambiguous', 'iEP', 'iEP', 'Non Differentiated', 'iEP',
#        'Fibroblast', 'iEP', 'iEP', 'Ambiguous', 'Non Differentiated',
#        'Ambiguous', 'iEP', 'iEP', 'Fibroblast', 'iEP', 'Ambiguous', 'iEP',
#        'Fibroblast', 'iEP', 'Ambiguous', 'iEP', 'Non Differentiated',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP',
#        'iEP', 'iEP', 'iEP', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'iEP', 'Ambiguous', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated',
#        'Ambiguous', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'Ambiguous',
#        'iEP', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Fibroblast', 'Non Differentiated',
#        'iEP', 'iEP', 'Fibroblast', 'Ambiguous', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated', 'iEP',
#        'Ambiguous', 'iEP', 'iEP', 'iEP', 'Fibroblast', 'Ambiguous',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'Ambiguous', 'Non Differentiated', 'iEP', 'Fibroblast', 'iEP',
#        'Fibroblast', 'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Ambiguous', 'Fibroblast', 'Fibroblast', 'Fibroblast',
#        'Fibroblast', 'Ambiguous', 'iEP', 'Fibroblast', 'Fibroblast',
#        'Ambiguous', 'Fibroblast', 'Fibroblast', 'iEP', 'Fibroblast',
#        'iEP', 'Ambiguous', 'Ambiguous', 'Fibroblast', 'iEP', 'Fibroblast',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Fibroblast', 'Non Differentiated', 'Ambiguous', 'iEP', 'iEP',
#        'iEP', 'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated',
#        'iEP', 'Fibroblast', 'iEP', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'iEP', 'Fibroblast', 'iEP', 'iEP', 'iEP',
#        'iEP', 'iEP', 'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Ambiguous', 'iEP', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Fibroblast', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Ambiguous', 'iEP', 'iEP', 'iEP',
#        'Fibroblast', 'Ambiguous', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Ambiguous', 'iEP', 'iEP', 'Non Differentiated', 'iEP',
#        'Fibroblast', 'iEP', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'Fibroblast',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Fibroblast', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'Fibroblast', 'Non Differentiated', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Ambiguous', 'Fibroblast', 'Ambiguous',
#        'Fibroblast', 'Fibroblast', 'Non Differentiated', 'Fibroblast',
#        'iEP', 'Ambiguous', 'Fibroblast', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'iEP', 'iEP', 'iEP', 'Non Differentiated', 'iEP', 'iEP', 'iEP',
#        'iEP', 'iEP', 'Ambiguous', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'Ambiguous', 'Ambiguous', 'iEP', 'Ambiguous',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'Ambiguous', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'Non Differentiated',
#        'Ambiguous', 'Fibroblast', 'Ambiguous', 'Fibroblast', 'Ambiguous',
#        'Ambiguous', 'Fibroblast', 'Fibroblast', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'Fibroblast',
#        'iEP', 'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP',
#        'Ambiguous', 'iEP', 'iEP', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'Ambiguous', 'iEP', 'Fibroblast',
#        'Non Differentiated', 'Fibroblast', 'Ambiguous', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'Ambiguous', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'Ambiguous', 'Non Differentiated', 'iEP',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Fibroblast', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Ambiguous', 'iEP', 'Non Differentiated', 'Non Differentiated',
#        'iEP', 'Non Differentiated', 'Fibroblast', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'Ambiguous',
#        'Fibroblast', 'Ambiguous', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'iEP', 'iEP',
#        'Ambiguous', 'Fibroblast', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Fibroblast', 'iEP', 'iEP',
#        'Ambiguous', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'Non Differentiated', 'iEP',
#        'iEP', 'iEP', 'iEP', 'Non Differentiated', 'Non Differentiated',
#        'Fibroblast', 'Ambiguous', 'Fibroblast', 'Ambiguous', 'Fibroblast',
#        'iEP', 'iEP', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'iEP', 'Non Differentiated', 'Ambiguous',
#        'iEP', 'Non Differentiated', 'iEP', 'iEP', 'Fibroblast',
#        'Ambiguous', 'Ambiguous', 'Non Differentiated', 'Ambiguous', 'iEP',
#        'iEP', 'iEP', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Fibroblast', 'iEP', 'Fibroblast', 'iEP',
#        'iEP', 'Fibroblast', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'iEP', 'Fibroblast', 'Non Differentiated',
#        'Fibroblast', 'iEP', 'Fibroblast', 'Fibroblast', 'Fibroblast',
#        'Non Differentiated', 'iEP', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Ambiguous', 'Fibroblast', 'Non Differentiated', 'Ambiguous',
#        'Non Differentiated', 'Non Differentiated', 'Fibroblast', 'iEP',
#        'Ambiguous', 'iEP', 'Non Differentiated', 'iEP', 'Fibroblast',
#        'iEP', 'Fibroblast', 'iEP', 'iEP', 'Non Differentiated',
#        'Fibroblast', 'Fibroblast', 'Fibroblast', 'Non Differentiated',
#        'iEP', 'Non Differentiated', 'Ambiguous', 'Non Differentiated',
#        'Ambiguous', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP', 'iEP',
#        'Non Differentiated', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'iEP', 'iEP', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Non Differentiated',
#        'Non Differentiated', 'Non Differentiated', 'Ambiguous',
#        'Fibroblast', 'Fibroblast', 'Fibroblast', 'iEP',
#        'Non Differentiated', 'Ambiguous', 'Non Differentiated', 'iEP',
#        'Non Differentiated', 'Fibroblast', 'Non Differentiated',
#        'Ambiguous', 'Fibroblast', 'iEP', 'Ambiguous',
#        'Non Differentiated', 'iEP'], dtype=object)

# %%
# Map each unique category to a specific color
unique_categories = np.unique(categories)
# Select a colormap
colormap = sns.color_palette("tab20", len(unique_categories))
category_to_color = {category: colormap[i] for i, category in enumerate(unique_categories)}

# Convert categories to colors
category_colors = np.array([category_to_color[category] for category in categories])

# Plot the UMAP embedding with dots colored according to 'categories'
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(x=embedding[:, 0], y=embedding[:, 1], hue=categories, palette=category_to_color, s=8, alpha=0.5)
plt.title(f'UMAP of scCL embedding of {num_cells} cells by Cell Types', fontsize=24)
plt.legend(title="cell type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
# plt.savefig(output_dir + f'/umap_of_scCL_embedding.png', dpi=300)
plt.show()

# %%
# Determine the top lineages
unique_labels, counts = np.unique(labels, return_counts=True)
top_lineages = unique_labels[np.argsort(-counts)[:num_top_lg_toplot]]

default_color = 'gray'

for i, lineage in enumerate(top_lineages):
    plt.figure(figsize=(12, 8))

    # Plot all other lineages first
    for label in np.unique(labels):
        if label != lineage:
            subset = embedding[labels == label]
            sns.scatterplot(x=subset[:, 0], y=subset[:, 1], color=default_color, s=1, alpha=0.2)

    # Plot the specific lineage on top, with colors according to categories
    subset = embedding[labels == lineage]
    subset_categories = categories[labels == lineage]
    subset_colors = np.array([category_to_color[category] for category in subset_categories])
    sns.scatterplot(x=subset[:, 0], y=subset[:, 1], hue=subset_categories, palette=category_to_color, s=25, alpha=1)

    plt.title(f'UMAP for 41201 Cells with #{i+1} Largest Lineage ({lineage}) Highlighted')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')

    # Create a legend for the categories present in the specific lineage
    subset_unique_categories = np.unique(subset_categories)
    handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=category_to_color[category], markersize=10) for category in subset_unique_categories]
    plt.legend(handles, subset_unique_categories, title="cell type", bbox_to_anchor=(1.05, 1), loc='upper left', markerscale=2)

    # plt.savefig(output_dir + f'/cell_umap_{i+1}_largest_plot.png', dpi=300)
    plt.show()
