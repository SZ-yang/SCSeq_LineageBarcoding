# %% [markdown]
# ### Hyperparameter:
# size factor:0.3
# batch size:280
# num_lineage_1batch: 70
# max epoch: 220
# temperature:0.5
#
# Execution time: 1.2 hours

# %%
import numpy as np
import anndata as ad
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import calinski_harabasz_score

# %%
# Load data
input_dir = "/Users/apple/Desktop/KB/data/LarryData"
X_scCL = np.load("/Users/apple/Desktop/KB/data/feat_722/scBaseEncoderFeat_Z_bs280_tau0.5.npy")
adata_subset = ad.read_h5ad(input_dir+'/Larry_41201_2000.h5ad')
lineage_label = adata_subset.obs["clone_id"].to_numpy()

# %%
X_scCL.shape ,lineage_label.shape
# Out:
# ((41201, 64), (41201,))

# %%
score_scCL = calinski_harabasz_score(X_scCL, lineage_label)

# %%
# previously score for size factor 0.3 and batch size of 15 is 48
score_scCL
# Out:
# 43.00660891493434

# %%
train_loss = np.load("/Users/apple/Desktop/KB/data/feat_722/train_losses_bs280_tau0.5.npy")

# %%
train_loss.shape
# Out:
# (220,)

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()
